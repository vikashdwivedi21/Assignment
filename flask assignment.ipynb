# %%
#Q1. What is Flask framework ? What are the advantages of Flask Framework.


"""Flask is a microframework for Python based on Werkzeug, Jinja2 and good intentions. It is designed to make getting started quick and easy, with the ability to scale up to complex applications.
Flask is a lightweight WSGI web application framework. It is designed to be simple and easy to use, with a focus on rapid development. Flask is also extensible, allowing users to add additional functionality through extensions.
Flask is a popular choice for Python web development, as it is easy to learn and use. It is also very flexible, allowing users to create a wide variety of web applications.
Some of the advantages of Flask include:
* It is lightweight and easy to use.
* It is extensible, allowing users to add additional functionality through extensions.
* It is well-documented and has a large community of users and developers.
* It is open source and free to use."""
# Out:
# 'Flask is a microframework for Python based on Werkzeug, Jinja2 and good intentions. It is designed to make getting started quick and easy, with the ability to scale up to complex applications.\nFlask is a lightweight WSGI web application framework. It is designed to be simple and easy to use, with a focus on rapid development. Flask is also extensible, allowing users to add additional functionality through extensions.\nFlask is a popular choice for Python web development, as it is easy to learn and use. It is also very flexible, allowing users to create a wide variety of web applications.\nSome of the advantages of Flask include:\n* It is lightweight and easy to use.\n* It is extensible, allowing users to add additional functionality through extensions.\n* It is well-documented and has a large community of users and developers.\n* It is open source and free to use.'

# %%
pip install Flask
# Out:
# ...
#                                               0.0/96.9 kB ? eta -:--:--
#      ------------                             30.7/96.9 kB 1.3 MB/s eta 0:00:01
#      ----------------                       41.0/96.9 kB 495.5 kB/s eta 0:00:01
#      --------------------------------       81.9/96.9 kB 573.4 kB/s eta 0:00:01
#      -------------------------------------- 96.9/96.9 kB 503.6 kB/s eta 0:00:00
# ...
#                                               0.0/242.5 kB ? eta -:--:--
#      -----                                    30.7/242.5 kB ? eta -:--:--
#      ---------                             61.4/242.5 kB 825.8 kB/s eta 0:00:01
#      ------------                          81.9/242.5 kB 919.0 kB/s eta 0:00:01
#      ----------------                     112.6/242.5 kB 731.4 kB/s eta 0:00:01
#      ------------------                   122.9/242.5 kB 722.1 kB/s eta 0:00:01
#      ---------------------                143.4/242.5 kB 568.9 kB/s eta 0:00:01
# ...

# %%
#Q2.Create a simple Flask application to display "Hello World!" and attach the screen shot of output
#in juypeter noteboo


from flask import Flask
from flask import request

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"
if __name__=="__main__":
   app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.43.131:5000
# Press CTRL+C to quit

# %%
from IPython.display import Image
Image(filename="C:\\Users\\vikas\\Pictures\\Screenshots\\Screenshot (4).png")

# %%
#Q4. Create a  "/welcome" rout the display Welcome message "Welcome to abc Corporation" and "/" 
#rout display the following message:
#   Company Name: ABC Corporation
#Location: India
#Contact Detail: 999-999-9999


from flask import Flask
from flask import request


app = Flask(__name__)
@app.route("/")
def company_details():
   
   
   
   company = {
       'Company Name': 'ABC Corporation',
        'Location': 'India',
       'Contact Detail': '999-999-9999'
   }

   return company

@app.route("/Welcome")
def Welcom():
    return "Welcome to ABC Corporation"


if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.43.131:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [13/Jul/2023 21:46:14] "GET / HTTP/1.1" 200 -

# %%
from IPython.display import Image
Image(filename="C:\\Users\\vikas\\Pictures\\Screenshots\\Screenshot 2023-07-13 214625.png")

# %%
#Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'Home Page'

@app.route('/about')
def about():
    return 'About Page'

@app.route('/contact')
def contact():
    return 'Contact Page'

if __name__ == '__main__':
    with app.test_request_context():
        print(url_for('home'))  
        print(url_for('about'))  
        print(url_for('contact'))
# Out:
# /
# /about
# /contact

# %%
/about
# Out:
# 'About Page'

# %%
/contact
# Out:
# 'Contact Page'
